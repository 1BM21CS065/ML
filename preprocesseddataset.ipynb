# %% [markdown]
# <a href="https://colab.research.google.com/github/1BM21CS065/ML/blob/main/preprocesseddataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv(r"/content/labeled_tweets.csv")

# %%
df1 = df.copy()

# %%
df1=df1.drop_duplicates(subset=['full_text'], keep=False)

# %%
df1.head()
# Out:
#               id      label                                          full_text
# 6   5.723350e+17  Offensive  of course you were born in serbia...you're as ...
# 7   5.723330e+17  Offensive  These girls are the equivalent of the irritati...
# 10  5.751740e+17  Offensive  RT @PhxKen: SIR WINSTON CHURCHHILL: "ISLAM IS ...
# 11  5.692940e+17  Offensive  RT @TheRightWingM: Giuliani watched his city a...
# 12  4.464610e+17  Offensive  RT @YesYoureRacist: At least you're only a tin...

# %%
df1
# Out:
#                  id      label  \
# 6      5.723350e+17  Offensive
# 7      5.723330e+17  Offensive
# 10     5.751740e+17  Offensive
# 11     5.692940e+17  Offensive
# 12     4.464610e+17  Offensive
# ...             ...        ...
# 11957           NaN  Offensive
# 11958           NaN  Offensive
# 11959           NaN  Offensive
# 11960           NaN  Offensive
# 11961           NaN  Offensive
#
#                                                full_text
# 6      of course you were born in serbia...you're as ...
# 7      These girls are the equivalent of the irritati...
# 10     RT @PhxKen: SIR WINSTON CHURCHHILL: "ISLAM IS ...
# 11     RT @TheRightWingM: Giuliani watched his city a...
# 12     RT @YesYoureRacist: At least you're only a tin...
# ...                                                  ...
# 11957                      @BitchImFancy lol so retarded
# 11958  @BitchImaStunna @VeshaaCouture lmao bitch shut up
# 11959  @BitchMedia what's up my bitches?! Shout out f...
# 11960  @Bitcheslovestar The only one of Mary's friend...
# 11961  @BitchsLoveMosa do these bitches really love M...
#
# [11792 rows x 3 columns]

# %%
df1.to_csv('/content/drive/MyDrive/miniproject/preprocessed.csv')

# %%
df1.head()
# Out:
#               id      label                                          full_text
# 6   5.723350e+17  Offensive  of course you were born in serbia...you're as ...
# 7   5.723330e+17  Offensive  These girls are the equivalent of the irritati...
# 10  5.751740e+17  Offensive  RT @PhxKen: SIR WINSTON CHURCHHILL: "ISLAM IS ...
# 11  5.692940e+17  Offensive  RT @TheRightWingM: Giuliani watched his city a...
# 12  4.464610e+17  Offensive  RT @YesYoureRacist: At least you're only a tin...

# %%
X = df1.iloc[:, :-1].values
y = df1.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train)
# Out:
# [[5.52993e+17 'Offensive']
#  [5.72345e+17 'Offensive']
#  [5.74363e+17 'Non-offensive']
#  ...
#  [5.6405e+17 'Offensive']
#  [5.75959e+17 'Non-offensive']
#  [5.72357e+17 'Offensive']]

# %%
print(X_test)
# Out:
# [[5.761e+17 'Non-offensive']
#  [5.75958e+17 'Non-offensive']
#  [5.64577e+17 'Offensive']
#  ...
#  [5.72331e+17 'Non-offensive']
#  [5.69283e+17 'Offensive']
#  [5.75959e+17 'Non-offensive']]

# %%
print(y_train)
print(y_test)
# Out:
# ['RT @NickCMcCarthy Not sexist, but girls on xbox live are super annoying.'
#  "I cannot stop looking at Nikki's dreadful black crooked bra #MKR #MKR2015"
#  "@jsigj @SuperSpacedad @Glinner that's his original account, renamed."
#  ...
#  '@bmackillopthio But, Trump gets called a megalomaniac.  Is that a gendered slur, too?  I never hear women called megalomaniacs.'
#  'ASH AND CAMILLA YES &lt;3 #mkr'
#  "@lilbeastunleash cos that's all they suck to get their jobs #MKR"]
# ["@freebsdglrI awww. someone's mad. &lt;3"
#  'Ha ha the look on Kats face when the judges delivered their critique #priceless #mkr @mykitchenrules'
#  '@boxedariel None of these things are true.  But I return to the original question...research. What have you read?'
#  ...
#  'On presentation alone, these girls shouldnt even make the final judging. 2 of 3 looked like dog food #mkr'
#  "http://t.co/hBBh4lcCqs @lathandd Women referees suck man. And no I'm not sexist but damn bruh that wasn't a good call"
#  "It's just not the same without Manu. \n\n#MKR"]
