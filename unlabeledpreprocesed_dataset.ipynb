# %% [markdown]
# <a href="https://colab.research.google.com/github/1BM21CS065/ML/blob/main/unlabeledpreprocesed_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv(r"/content/labeled_tweets.csv")

# %%
df1 = df.copy()

# %%
df1=df1.drop_duplicates(subset=['full_text'], keep=False)

# %%
df1.head()
# Out:
#               id      label                                          full_text
# 6   5.723350e+17  Offensive  of course you were born in serbia...you're as ...
# 7   5.723330e+17  Offensive  These girls are the equivalent of the irritati...
# 10  5.751740e+17  Offensive  RT @PhxKen: SIR WINSTON CHURCHHILL: "ISLAM IS ...
# 11  5.692940e+17  Offensive  RT @TheRightWingM: Giuliani watched his city a...
# 12  4.464610e+17  Offensive  RT @YesYoureRacist: At least you're only a tin...

# %%
df1.to_csv('/content/drive/MyDrive/miniproject/preprocessed.csv')

# %%
df1.drop(['label'], axis=1, inplace=True)

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#                 id                                          full_text
# 6     5.723350e+17  of course you were born in serbia...you're as ...
# 7     5.723330e+17  These girls are the equivalent of the irritati...
# 10    5.751740e+17  RT @PhxKen: SIR WINSTON CHURCHHILL: "ISLAM IS ...
# 11    5.692940e+17  RT @TheRightWingM: Giuliani watched his city a...
# 12    4.464610e+17  RT @YesYoureRacist: At least you're only a tin...
# ...            ...                                                ...
# 9433  5.723310e+17  mmmm #MKR getting v boring @lisamromano @garyd...
# 9434  5.723310e+17  "Sass" 😆😈😆\nRT @arna_jane: They say sass one m...
# 9435  5.723310e+17  “@jgto: Steve’s starting to annoy me #MKR”\n\n...
# 9436  5.723310e+17  “@4Cate: Has Colin outside for a smoke  #mkr”\...
# 9437  5.605950e+17                    "@panelrific: Let's go 🐧🐧🐧🐧🐧🐧😃"
#
# [9268 rows x 2 columns]

# %%
X = df1.iloc[:, :-1].values
y = df1.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train)
# Out:
# [[5.75847e+17]
#  [5.72336e+17]
#  [5.62705e+17]
#  ...
#  [5.64050e+17]
#  [5.75959e+17]
#  [5.72357e+17]]

# %%
print(X_test)
# Out:
# [[4.28014e+17]
#  [5.66318e+17]
#  [5.60440e+17]
#  ...
#  [3.83628e+17]
#  [5.72335e+17]
#  [5.64138e+17]]

# %%
print(y_train)
# Out:
# ['RT @join_oapi: Revenge Porn and doxxing was just banned from Twitter. http://t.co/e0LndwyWJA https://t.co/m2ZigUXYSh'
#  'Another round of instant restaurants! #MKR This competition should finish sometime in 2018'
#  '#stopwadhwa2015 because he is developing ties to gamergate. Relies on their support, talks to Milo.'
#  ...
#  '@bmackillopthio But, Trump gets called a megalomaniac.  Is that a gendered slur, too?  I never hear women called megalomaniacs.'
#  'ASH AND CAMILLA YES &lt;3 #mkr'
#  "@lilbeastunleash cos that's all they suck to get their jobs #MKR"]

# %%
print(y_test)
# Out:
# ["You've got to follow @WhiteLiberalism." '@Rose_And_Copper Yeah.'
#  '@TheGags29 @JustLaurenB @AgentPatriarch7 @ZKotek @The_Loki_Jotunn @MyLostGadget DOJ is quoting same small sample survey you already cited...'
#  ...
#  "RT @SxFlint93: I'm not sexist but women should play football past the age of 12 unless they're over 285"
#  'I would have thought the sassy sisters would leave of their own volition. There’s only room for one girl team, right? #mkr'
#  'RT @CathyYoung63: To @MHarrisPerry, #BlackLivesMatter obviously does not include Brian Banks, whose life was nearly destroyed by false rape…']
